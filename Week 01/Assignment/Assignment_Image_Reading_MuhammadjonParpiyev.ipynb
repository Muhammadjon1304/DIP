# %% [markdown]
# # 🎓 Assignment: Reading and Visualizing Images in Python
#
# **Course:** Introduction to Image Processing / Computer Vision
# **Level:** Undergraduate / Early Graduate
# **Format:** Jupyter Notebook
#
# ---
#
# ## 📌 Learning Objectives
# By the end of this assignment, students will be able to:
#
# - Read images using different Python libraries
# - Understand differences between image formats and data types
# - Convert between color spaces
# - Visualize and process images using NumPy-based tools
#
# ---
#
# ## 📝 Instructions
#
# - Complete all **TODO** sections.
# - Run each cell after writing your code.
# - Add short comments explaining *what your code does*.
# - Submit the completed notebook (`.ipynb`).

# %% [markdown]
# ## 🔹 Part 1: Using PIL (Pillow)
#
# PIL loads images as **PIL Image objects**, not NumPy arrays.

# %%
# TODO 1:
# 1. Open the image "images/test_image.jpg" using PIL
# 2. Print the image type, size, and mode
# 3. Display the image

from PIL import Image

# Open the image using PIL
img_pil = Image.open('images.jpeg')

# Print image properties
print(f"Image type: {type(img_pil)}")
print(f"Image size: {img_pil.size}")
print(f"Image mode: {img_pil.mode}")

# Display the image
img_pil.show()
# Out:
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Image size: (275, 183)
# Image mode: RGB

# %% [markdown]
# ### ✨ Task 1.1: PIL → NumPy Conversion

# %%
# TODO 2:
# Convert the PIL image to a NumPy array
# Print the array shape and data type

import numpy as np

# Convert PIL image to NumPy array
img_array = np.array(img_pil)

# Print array properties
print(f"Array shape: {img_array.shape}")
print(f"Array data type: {img_array.dtype}")

# %% [markdown]
# ## 🔹 Part 2: Matplotlib Image Reading
#
# Matplotlib reads images directly as NumPy arrays.

# %%
# TODO 3:
# 1. Read the image using matplotlib.image.imread
# 2. Print its shape
# 3. Display it using plt.imshow

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# Read image using matplotlib
img_mpl = mpimg.imread('images.jpeg')

# Print shape
print(f"Image shape: {img_mpl.shape}")

# Display the image
plt.figure(figsize=(8, 6))
plt.imshow(img_mpl)
plt.axis('off')
plt.title("Image loaded with Matplotlib")
plt.show()

# %% [markdown]
# ### ❓ Concept Question
# **Q:** Why does Matplotlib treat images as NumPy arrays?
#
# **Answer:** Matplotlib treats images as NumPy arrays because this format allows for efficient numerical operations, compatibility with scientific computing tools, and flexible manipulation of pixel data. NumPy arrays enable vectorized operations that are much faster than iterating through individual pixels, making them ideal for image processing tasks.

# %% [markdown]
# ## 🔹 Part 3: scikit-image
#
# scikit-image works with well-defined data ranges.

# %%
# TODO 4:
# 1. Read the image using skimage.io.imread
# 2. Convert it to float using img_as_float
# 3. Print min and max pixel values
# 4. Display the image

from skimage import io, img_as_float
import matplotlib.pyplot as plt

# Read image using scikit-image
img_ski = io.imread('images.jpeg')

# Convert to float
img_float = img_as_float(img_ski)

# Print min and max pixel values
print(f"Min pixel value: {img_float.min()}")
print(f"Max pixel value: {img_float.max()}")

# Display the image
plt.figure(figsize=(8, 6))
plt.imshow(img_float)
plt.axis('off')
plt.title("Image loaded with scikit-image (float)")
plt.show()

# %% [markdown]
# ### ✨ Task 3.1: Data Type Exploration
#
# **Q:** Why is using `astype(float)` discouraged compared to `img_as_float`?
#
# **Answer:** `img_as_float` is preferred because it properly normalizes pixel values to the [0, 1] range, handles different input data types correctly, and is specifically designed for image processing. Using `astype(float)` just converts data type without proper scaling (e.g., 255 stays as 255 instead of becoming 1.0), which can cause incorrect calculations and visualization issues.

# %% [markdown]
# ## 🔹 Part 4: OpenCV
#
# ⚠️ OpenCV loads color images in **BGR** format.

# %%
# TODO 5:
# 1. Read the image in grayscale and color using OpenCV
# 2. Convert the color image from BGR to RGB
# 3. Display the RGB image using matplotlib

import cv2
import matplotlib.pyplot as plt

# Read image in grayscale
img_gray = cv2.imread('images.jpeg', cv2.IMREAD_GRAYSCALE)

# Read image in color (default BGR)
img_bgr = cv2.imread('images.jpeg')

# Convert BGR to RGB
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

# Display the RGB image
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.imshow(img_gray, cmap='gray')
plt.axis('off')
plt.title("Grayscale Image")

plt.subplot(1, 2, 2)
plt.imshow(img_rgb)
plt.axis('off')
plt.title("RGB Image")
plt.show()

# %% [markdown]
# ### ✨ Task 4.1: Image Processing
#
# Apply **Canny edge detection** on the grayscale image and display the result.

# %%
# TODO 6:
# Perform edge detection using cv2.Canny

# Apply Canny edge detection
edges = cv2.Canny(img_gray, 100, 200)

# Display edge detection result
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.imshow(img_gray, cmap='gray')
plt.axis('off')
plt.title("Original Grayscale")

plt.subplot(1, 2, 2)
plt.imshow(edges, cmap='gray')
plt.axis('off')
plt.title("Canny Edge Detection")
plt.show()

# %% [markdown]
# ## 🔹 Part 5: Advanced Formats (Optional Bonus)
#
# These formats are common in **biomedical imaging**.

# %% [markdown]
# ### ⭐ Bonus Task A: OME-TIFF
#
# - Read an OME-TIFF file
# - Print the image shape
# - Inspect metadata

# %%
# BONUS (Optional)
# Uncomment and complete if the library and file are available

# from apeer_ometiff_library import io
# img, omexml = io.read_ometiff("images/test_image.ome.tif")
# print(img.shape)

# %% [markdown]
# ### ⭐ Bonus Task B: Reading Multiple Images
#
# Read all images from a folder and display them one by one.

# %%
# BONUS (Optional)

import glob
import cv2
import matplotlib.pyplot as plt

# path = "images/test_images/aeroplane/*.*"
# for file in glob.glob(path):
#     # YOUR CODE HERE

# %% [markdown]
# ## 📊 Reflection Questions
#
# 1. **Which library did you find easiest to use? Why?**
#    - Honestly, Matplotlib felt the most natural to work with. Since it automatically converts images into NumPy arrays, everything integrates seamlessly with the data science workflow I'm already familiar with. I didn't have to jump through hoops converting between formats—it just works. PIL is intuitive too, but the extra conversion step makes it feel like one more thing to remember.
#
# 2. **Which library would you choose for real-time video processing?**
#    - Without a doubt, OpenCV. It's built specifically for this kind of work, and you can tell. The performance is noticeably better, and it has all the specialized functions you'd need out of the box. The other libraries are great for static images, but OpenCV just feels like home for anything that involves video or real-time processing.
#
# 3. **What is the main difference between RGB and BGR?**
#    - The order matters more than you'd think! RGB is the standard (Red first, then Green, Blue), which is what most libraries expect. But OpenCV decided to do its own thing with BGR. So when I load an image with OpenCV, the red and blue channels are swapped. That's why I had to explicitly convert—otherwise red would look blue and vice versa. It's a small thing, but it tripped me up at first!

# %% [markdown]
# ## ✅ Submission Checklist
#
# - [x] All TODOs completed
# - [x] Code runs without errors
# - [x] Reflection questions answered
#
# **File name:** `Assignment_Image_Reading_MuhammadjonParpiyev.ipynb`
